# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
#pip install gmaps

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# %%
# Import API key
from config import g_key
#print(g_key)

# %%
# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID             City Country                 Date  \
# 0        0         Hamilton      US  2021-12-21 17:10:44
# 1        1         Luderitz     NaN  2021-12-21 17:10:44
# 2        2  Arraial Do Cabo      BR  2021-12-21 17:10:44
# 3        3          Rikitea      PF  2021-12-21 17:08:46
# 4        4       Nikolskoye      RU  2021-12-21 17:08:49
#
#     Current Description      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         broken clouds  39.1834  -84.5333     43.12        78          75
# 1             clear sky -26.6481   15.1594     65.77        71           0
# 2             clear sky -22.9661  -42.0278     80.46        65           0
# 3  heavy intensity rain -23.1203 -134.9692     72.90        90         100
# 4       overcast clouds  59.7035   30.7861      9.79        93         100
#
#    Wind Speed
# 0        1.01
# 1        5.08
# 2       14.97
# 3       12.03
# 4        7.20

# %%
fig=gmaps.figure()
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
#Module 6.5.3
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 78
# What is the maximum temperature you would like for your trip? 85

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.

# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID             City Country                 Date Current Description  \
# 2         2  Arraial Do Cabo      BR  2021-12-21 17:10:44           clear sky
# 13       13         Cidreira      BR  2021-12-21 17:10:48           clear sky
# 15       15             Tual      ID  2021-12-21 17:10:48     overcast clouds
# 30       30     Quatre Cocos      MU  2021-12-21 17:10:52          light rain
# 31       31            Vaini      TO  2021-12-21 17:08:53          light rain
# 33       33   Saint-Philippe      RE  2021-12-21 17:10:53          light rain
# 35       35        Mahebourg      MU  2021-12-21 17:08:50          light rain
# 38       38       Nouakchott      MR  2021-12-21 17:08:46     overcast clouds
# 43       43          Kavieng      PG  2021-12-21 17:10:55          light rain
# 52       52         Souillac      MU  2021-12-21 17:11:57       broken clouds
#
#         Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 2  -22.9661  -42.0278     80.46        65           0       14.97
# 13 -30.1811  -50.2056     79.25        66           4       10.40
# 15  -5.6667  132.7500     82.60        79         100       10.36
# 30 -20.2078   57.7625     78.91        80          99       14.70
# 31 -21.2000 -175.2000     78.96        94          75        6.91
# 33 -21.3585   55.7679     78.39        87          74       12.01
# 35 -20.4081   57.7000     79.09        78          75       12.66
# 38  18.0858  -15.9785     80.53        37         100        2.13
# 43  -2.5744  150.7967     81.82        79         100        7.90
# 52 -20.5167   57.5167     79.18        78          75       12.66

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119 entries, 2 to 684
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City_ID              119 non-null    int64
#  1   City                 119 non-null    object
#  2   Country              118 non-null    object
#  3   Date                 119 non-null    object
#  4   Current Description  119 non-null    object
#  5   Lat                  119 non-null    float64
#  6   Lng                  119 non-null    float64
#  7   Max Temp             119 non-null    float64
#  8   Humidity             119 non-null    int64
#  9   Cloudiness           119 non-null    int64
#  10  Wind Speed           119 non-null    float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 11.2+ KB

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.copy()
clean_df.dropna(how='any', inplace=True)
clean_df
# Out:
#      City_ID             City Country                 Date  \
# 2          2  Arraial Do Cabo      BR  2021-12-21 17:10:44
# 13        13         Cidreira      BR  2021-12-21 17:10:48
# 15        15             Tual      ID  2021-12-21 17:10:48
# 30        30     Quatre Cocos      MU  2021-12-21 17:10:52
# 31        31            Vaini      TO  2021-12-21 17:08:53
# ..       ...              ...     ...                  ...
# 622      622      Grand-Lahou      CI  2021-12-21 17:27:08
# 644      644           Mangai      CD  2021-12-21 17:27:15
# 661      661            Kudat      MY  2021-12-21 17:28:20
# 671      671            Wajir      KE  2021-12-21 17:28:23
# 684      684             Luba      GQ  2021-12-21 17:28:26
#
#     Current Description      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 2             clear sky -22.9661  -42.0278     80.46        65           0
# 13            clear sky -30.1811  -50.2056     79.25        66           4
# 15      overcast clouds  -5.6667  132.7500     82.60        79         100
# 30           light rain -20.2078   57.7625     78.91        80          99
# 31           light rain -21.2000 -175.2000     78.96        94          75
# ..                  ...      ...       ...       ...       ...         ...
# 622       broken clouds   5.1367   -5.0242     83.46        68          76
# 644     overcast clouds  -4.0500   19.5333     79.54        74          99
# 661          few clouds   6.8837  116.8477     82.33        83          20
# 671        thunderstorm   1.7471   40.0573     80.56        74          75
# 684       broken clouds   3.4568    8.5547     84.09        67          66
#
#      Wind Speed
# 2         14.97
# 13        10.40
# 15        10.36
# 30        14.70
# 31         6.91
# ..          ...
# 622       10.29
# 644        1.68
# 661        4.61
# 671        0.00
# 684       10.45
#
# [118 rows x 11 columns]

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    
    # 6c. Get latitude and longitude from DataFrame
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data
    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    # 6e. Make request and retrieve the JSON data from the search.
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    # Grab the first hotel from the results and store the name.
    #Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna(how='any')
clean_hotel_df
# Out:
#                 City Country  Max Temp Current Description      Lat       Lng  \
# 2    Arraial Do Cabo      BR     80.46           clear sky -22.9661  -42.0278
# 13          Cidreira      BR     79.25           clear sky -30.1811  -50.2056
# 15              Tual      ID     82.60     overcast clouds  -5.6667  132.7500
# 30      Quatre Cocos      MU     78.91          light rain -20.2078   57.7625
# 31             Vaini      TO     78.96          light rain -21.2000 -175.2000
# ..               ...     ...       ...                 ...      ...       ...
# 622      Grand-Lahou      CI     83.46       broken clouds   5.1367   -5.0242
# 644           Mangai      CD     79.54     overcast clouds  -4.0500   19.5333
# 661            Kudat      MY     82.33          few clouds   6.8837  116.8477
# 671            Wajir      KE     80.56        thunderstorm   1.7471   40.0573
# 684             Luba      GQ     84.09       broken clouds   3.4568    8.5547
#
#                           Hotel Name
# 2                Pousada Porto Praia
# 13                     Hotel Castelo
# 15                 Grand Vilia Hotel
# 30            Sunrise Attitude Hotel
# 31               Keleti Beach Resort
# ..                               ...
# 622   Hotel Beatitude de Grand Lahou
# 644
# 661               Dream Garden Hotel
# 671  Al-bustan Hotel And Restaurant.
# 684
#
# [118 rows x 7 columns]

# %%
# 8a. Create the output File (CSV)
output_data_file = "./Vacation_Search/WeatherPy_vacation.csv"

# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
#Note you will likely need to switch to jupyter notebook
# Out:
# ['\n<dl>\n<dt>City</dt><dd>Arraial Do Cabo</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>80.46 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Cidreira</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>79.25 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Tual</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>82.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Quatre Cocos</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Weather Description</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>78.91 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Vaini</dd>\n<dt>Country</dt><dd>TO</dd>\n<dt>Weather Description</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>78.96 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Saint-Philippe</dd>\n<dt>Country</dt><dd>RE</dd>\n<dt>Weather Description</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>78.39 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Mahebourg</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Weather Description</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>79.09 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Nouakchott</dd>\n<dt>Country</dt><dd>MR</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>80.53 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Kavieng</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Weather Description</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>81.82 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Souillac</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>79.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Gusau</dd>\n<dt>Country</dt><dd>NG</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>80.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Padang</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>78.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Lorengau</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Weather Description</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>81.12 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Puerto Ayora</dd>\n<dt>Country</dt><dd>EC</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>78.76 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Butaritari</dd>\n<dt>Country</dt><dd>KI</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>81.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Faanui</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>78.57 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Kirakira</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>79.59 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Djibo</dd>\n<dt>Country</dt><dd>BF</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>83.23 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Port Elizabeth</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>79.11 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Caravelas</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>78.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Georgetown</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>78.73 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Malindi</dd>\n<dt>Country</dt><dd>KE</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>81.19 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Sao Raimundo Das Mangabeiras</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>84.49 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Cockburn Town</dd>\n<dt>Country</dt><dd>TC</dd>\n<dt>Weather Description</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>82.36 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Bubaque</dd>\n<dt>Country</dt><dd>GW</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>82.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Hithadhoo</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>82.08 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Labuan</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>78.96 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Abong Mbang</dd>\n<dt>Country</dt><dd>CM</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>81.34 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Pedernales</dd>\n<dt>Country</dt><dd>DO</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>82.22 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Itanhem</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>79.88 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Bambous Virieux</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Weather Description</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>79.05 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Sao Joao Da Barra</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>80.69 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Alofi</dd>\n<dt>Country</dt><dd>NU</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>79.36 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Grand Gaube</dd>\n<dt>Country</dt><dd>MU</dd>\n<dt>Weather Description</dt><dd>moderate rain</dd>\n<dt>Max Temp</dt><dd>79.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Matadi</dd>\n<dt>Country</dt><dd>CD</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>83.88 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Alice Springs</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>80.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Bengkulu</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>78.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Madimba</dd>\n<dt>Country</dt><dd>TZ</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>78.57 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Tres Arroyos</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>84.76 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Belmonte</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>79.3 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Bulungu</dd>\n<dt>Country</dt><dd>CD</dd>\n<dt>Weather Description</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>78.13 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Atuona</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>78.46 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Bathsheba</dd>\n<dt>Country</dt><dd>BB</dd>\n<dt>Weather Description</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>84.81 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Miracema Do Tocantins</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>83.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Manokwari</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>heavy intensity rain</dd>\n<dt>Max Temp</dt><dd>78.67 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Coihueco</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>83.14 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Garowe</dd>\n<dt>Country</dt><dd>SO</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>78.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Aloleng</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>79.05 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Hobyo</dd>\n<dt>Country</dt><dd>SO</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>78.03 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Manggar</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>78.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Neiafu</dd>\n<dt>Country</dt><dd>TO</dd>\n<dt>Weather Description</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>79.48 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>San Policarpo</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Weather Description</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>79.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Tombouctou</dd>\n<dt>Country</dt><dd>ML</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>78.35 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Sorong</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>80.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Beira</dd>\n<dt>Country</dt><dd>MZ</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>78.89 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Waingapu</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>80.42 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Tefe</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>moderate rain</dd>\n<dt>Max Temp</dt><dd>80.71 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Sumenep</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>78.96 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Sambava</dd>\n<dt>Country</dt><dd>MG</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>80.22 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Andros Town</dd>\n<dt>Country</dt><dd>BS</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>80.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Mana</dd>\n<dt>Country</dt><dd>GF</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>82.54 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Puxinana</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>83.98 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Santa Cruz</dd>\n<dt>Country</dt><dd>BO</dd>\n<dt>Weather Description</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>82.45 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Saint-Pierre</dd>\n<dt>Country</dt><dd>RE</dd>\n<dt>Weather Description</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>78.48 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Tarakan</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>78.3 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Nacala</dd>\n<dt>Country</dt><dd>MZ</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>78.69 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Barra Patuca</dd>\n<dt>Country</dt><dd>HN</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>82.71 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Banjar</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>84.06 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Taganak</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>82.54 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Saint-Raphael</dd>\n<dt>Country</dt><dd>HT</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>84.65 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Alto Araguaia</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>81.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Ntoum</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Weather Description</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>81.59 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Nova Olimpia</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>82.71 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Nampula</dd>\n<dt>Country</dt><dd>MZ</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>80.55 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Tautira</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>80.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Poum</dd>\n<dt>Country</dt><dd>NC</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>79.95 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Vanimo</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>78.51 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Gigmoto</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>78.73 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Auki</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>78.28 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Jeremie</dd>\n<dt>Country</dt><dd>HT</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>82.67 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Bandiagara</dd>\n<dt>Country</dt><dd>ML</dd>\n<dt>Weather Description</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>83.7 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Male</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>82.49 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Lakatoro</dd>\n<dt>Country</dt><dd>VU</dd>\n<dt>Weather Description</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>79.9 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Letlhakeng</dd>\n<dt>Country</dt><dd>BW</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>81.66 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Singaraja</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>78.89 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Tonj</dd>\n<dt>Country</dt><dd>SS</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>80.82 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Port Keats</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>82.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Rock Sound</dd>\n<dt>Country</dt><dd>BS</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>78.93 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Amapa</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>84.61 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Tevaitoa</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>78.64 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Mogadishu</dd>\n<dt>Country</dt><dd>SO</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>79.43 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Port-Gentil</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>82.36 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Wanlaweyn</dd>\n<dt>Country</dt><dd>SO</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>79.61 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Labrea</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>81.37 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Sinnamary</dd>\n<dt>Country</dt><dd>GF</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>81.7 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Buala</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>79.75 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Edd</dd>\n<dt>Country</dt><dd>ER</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>80.06 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Atar</dd>\n<dt>Country</dt><dd>MR</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>81.61 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Morondava</dd>\n<dt>Country</dt><dd>MG</dd>\n<dt>Weather Description</dt><dd>clear sky</dd>\n<dt>Max Temp</dt><dd>81.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Amahai</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>heavy intensity rain</dd>\n<dt>Max Temp</dt><dd>78.93 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>San Felipe</dd>\n<dt>Country</dt><dd>VE</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>83.32 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Cozumel</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Weather Description</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>80.67 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Mitu</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>81.1 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Manuk Mangkaw</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>82.17 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>George Town</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Weather Description</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>78.75 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Muisne</dd>\n<dt>Country</dt><dd>EC</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>80.71 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Siyabuswa</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>78.42 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Ilebo</dd>\n<dt>Country</dt><dd>CD</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>79.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Barra Do Corda</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>84.06 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Vallenar</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>83.53 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Namatanai</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>79.52 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Akonolinga</dd>\n<dt>Country</dt><dd>CM</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>83.66 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Mitsamiouli</dd>\n<dt>Country</dt><dd>KM</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>82.69 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Grand-Lahou</dd>\n<dt>Country</dt><dd>CI</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>83.46 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Mangai</dd>\n<dt>Country</dt><dd>CD</dd>\n<dt>Weather Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>79.54 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Kudat</dd>\n<dt>Country</dt><dd>MY</dd>\n<dt>Weather Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>82.33 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Wajir</dd>\n<dt>Country</dt><dd>KE</dd>\n<dt>Weather Description</dt><dd>thunderstorm</dd>\n<dt>Max Temp</dt><dd>80.56 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>City</dt><dd>Luba</dd>\n<dt>Country</dt><dd>GQ</dd>\n<dt>Weather Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>84.09 °F</dd>\n</dl>\n']

# %%
#Check to get map working
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

# 11a. Add a marker layer for each city to the map. 
marker_layer=gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
